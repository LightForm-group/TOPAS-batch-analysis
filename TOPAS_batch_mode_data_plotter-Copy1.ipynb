# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filenumber=65
filename='results_{:03d}.txt'.format(filenumber)
print(filename)
# Out:
# results_065.txt

# %%
DataArray=np.loadtxt(filename, usecols=(2,4,6,8,10,12))
print(DataArray)
# Out:
# [[ 13.1314       0.4121       2.91878932   4.66320028  86.23926492
#     3.18850496]
#  [ 12.9644       0.4072       2.91880867   4.66327286  86.16536256
#     3.18848462]
#  [ 13.0605       0.4099       2.91880907   4.6632109   86.14989821
#     3.18841098]
#  ...,
#  [ 14.4783       0.401        2.92013656   4.66482801  80.8093957
#     3.22006097]
#  [ 14.493        0.4015       2.920137     4.664828    80.80939996
#     3.220061  ]
#  [ 14.5875       0.4032       2.920137     4.664828    80.80939996
#     3.220061  ]]

# %%
filelength=len(DataArray)
print(filelength)
# Out:
# 5657

# %%
Data_Rwp=np.loadtxt(filename, usecols=(2))
Data_GOF=np.loadtxt(filename, usecols=(4))

Data_alpha_a=np.loadtxt(filename, usecols=(6))
Data_alpha_c=np.loadtxt(filename, usecols=(8))
Data_alpha_wt=np.loadtxt(filename, usecols=(10))

Data_beta_a=np.loadtxt(filename, usecols=(12))
Data_beta_wt=np.loadtxt(filename, usecols=(14))

print(Data_Rwp)
print(Data_GOF)
print(Data_alpha_a)
print(Data_alpha_c)
print(Data_alpha_wt)
print(Data_beta_a)
print(Data_beta_wt)
# Out:
# [ 13.1314  12.9644  13.0605 ...,  14.4783  14.493   14.5875]
# [ 0.4121  0.4072  0.4099 ...,  0.401   0.4015  0.4032]
# [ 2.91878932  2.91880867  2.91880907 ...,  2.92013656  2.920137    2.920137  ]
# [ 4.66320028  4.66327286  4.6632109  ...,  4.66482801  4.664828    4.664828  ]
# [ 86.23926492  86.16536256  86.14989821 ...,  80.8093957   80.80939996
#   80.80939996]
# [ 3.18850496  3.18848462  3.18841098 ...,  3.22006097  3.220061    3.220061  ]
# [ 13.76073508  13.83463744  13.85010179 ...,  19.1906043   19.19060004
#   19.19060004]

# %%
np.shape(Data_Rwp)
# Out:
# (5657,)

# %%
Image_Number=np.arange(1,filelength+1,1)
np.shape(Image_Number)
print(Image_Number)
# Out:
# [   1    2    3 ..., 5655 5656 5657]

# %%
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
#plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2,size=10)
plt.rc('xtick.minor', width=2, size=5)
plt.rc('ytick.major',width=2,size=10)
plt.rc('ytick.minor',width=2,size=5)

# %%
plt.figure(figsize=(10,8))

plt.minorticks_on()

plt.plot(Image_Number[:],Data_Rwp[:],color='black',linewidth=5);

plt.xlabel('Image Number', fontsize=28)
#plt.ylabel('${R_wp}$ Value', fontsize=28)
plt.ylabel('$\mathrm{R_{wp}}$ Value', fontsize=28)

plt.ylim(0,60)
plt.xlim(0,filelength)

#plt.legend()

plt.savefig('Rwp_{:03d}.png'.format(filenumber))

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.minorticks_on()

plt.plot(Image_Number[:],Data_GOF[:],color='darkviolet',linewidth=5 );

plt.xlabel('Image Number', fontsize=28)
plt.ylabel('GOF Value', fontsize=28)

plt.ylim(0,2)
plt.xlim(0,filelength)

#plt.legend()

plt.savefig('GOF_{:03d}.png'.format(filenumber))

plt.show()

# %%
Seconds=Image_Number/10

plt.figure(figsize=(10,3.5))

plt.minorticks_on()
##### need to use double slash with alpha and beta characters for some reason...#####
plt.plot(Seconds[:],Data_alpha_c[:],label='${\\alpha_c}$',color='maroon',linewidth=5)
plt.plot(Seconds[:],Data_beta_a[:],label='${\\beta_a}$',color='purple',linewidth=5)
plt.plot(Seconds[:],Data_alpha_a[:], label='${\\alpha_a}$', color='green',linewidth=5 );

plt.xlabel('Image Number', fontsize=28)
plt.ylabel('Lattice Parameter, ${\\AA}$ ', fontsize=28)

#all
# plt.ylim(2.9,4.8)
# plt.xlim(0,565.7)

#alpha c-parameter
plt.ylim(4.7220,4.7250)
plt.xlim(310,340)

#alpha a-parameter
# plt.ylim(2.9495,2.9525)
# plt.xlim(310,340)
# plt.yticks(np.arange(2.950, 2.953, 0.001))
#from... plt.xticks(np.arange(min(x), max(x)+1, 1.0))

#beta a-parameter
# plt.ylim(3.2825,3.2855)
# plt.xlim(310,340)

# plt.legend()

plt.tight_layout()

# plt.savefig('Lattice.png')

plt.show()

# %%
Seconds=Image_Number/10

fig,((ax1),(ax2),(ax3))=plt.subplots(3, 1, figsize=(20,10))

ax1.plot(Seconds[:],Data_alpha_c[:],label='${\\alpha_c}$',color='red',linewidth=5)
# ax1.set_xlim(260,300)
# ax1.set_ylim(5.165,5.190)
ax1.minorticks_on()
ax1.legend(loc=1, bbox_to_anchor=(0.125,1), prop={'size': 25}) #top left
# ax1.legend(loc=1, bbox_to_anchor=(0.125,0.42), prop={'size': 25}) #bottom left

ax2.set_ylabel('Lattice Parameter, ${\\AA}$ ', fontsize=36)
ax2.yaxis.set_label_coords(-0.07,0.5)
ax2.plot(Seconds[:],Data_alpha_a[:], label='${\\alpha_a}$', color='green',linewidth=5)
# ax2.set_xlim(260,300)
# ax2.set_ylim(3.227,3.252)
ax2.minorticks_on()
ax2.legend(loc=1, bbox_to_anchor=(0.125,1), prop={'size': 25}) #top left
# ax2.legend(loc=1, bbox_to_anchor=(0.125,0.42), prop={'size': 25}) #bottom left

ax3.plot(Seconds[:],Data_beta_a[:],label='${\\beta_a}$',color='blue',linewidth=5)
ax3.set_xlabel('Time, s', fontsize=36)
# ax3.set_xlim(260,300)
# ax3.set_ylim(3.55,3.575)
ax3.minorticks_on()
ax3.legend(loc=1, bbox_to_anchor=(0.125,1), prop={'size': 25}) #top left
# ax3.legend(loc=1, bbox_to_anchor=(0.125,0.42), prop={'size': 25}) #bottom left

# fig.tight_layout()

plt.savefig('Lattice_Full_{:03d}.png'.format(filenumber))

plt.show()

# %%
Seconds=Image_Number/10

fig,((ax1),(ax2),(ax3))=plt.subplots(3, 1, figsize=(20,10))

ax1.plot(Seconds[:],Data_alpha_c[:],label='${\\alpha_c}$',color='red',linewidth=5)
ax1.set_xlim(285,325)
ax1.set_ylim(5.1775,5.1975)
ax1.minorticks_on()
# ax1.legend(loc=1, bbox_to_anchor=(0.125,1), prop={'size': 25}) #top left
ax1.legend(loc=1, bbox_to_anchor=(0.125,0.42), prop={'size': 25}) #bottom left

ax2.set_ylabel('Lattice Parameter, ${\\AA}$ ', fontsize=36)
ax2.yaxis.set_label_coords(-0.07,0.5)
ax2.plot(Seconds[:],Data_alpha_a[:], label='${\\alpha_a}$', color='green',linewidth=5)
ax2.set_xlim(285,325)
ax2.set_ylim(3.233,3.253)
ax2.minorticks_on()
ax2.legend(loc=1, bbox_to_anchor=(0.125,1), prop={'size': 25}) #top left
# ax2.legend(loc=1, bbox_to_anchor=(0.125,0.42), prop={'size': 25}) #bottom left

ax3.plot(Seconds[:],Data_beta_a[:],label='${\\beta_a}$',color='blue',linewidth=5)
ax3.set_xlabel('Time, s', fontsize=36)
ax3.set_xlim(285,325)
ax3.set_ylim(3.575,3.595)
ax3.minorticks_on()
ax3.legend(loc=1, bbox_to_anchor=(0.125,1), prop={'size': 25}) #top left
# ax3.legend(loc=1, bbox_to_anchor=(0.125,0.42), prop={'size': 25}) #bottom left

# fig.tight_layout()

plt.savefig('Lattice_Deform_{:03d}.png'.format(filenumber))

plt.show()

# %%
np.arange(2.950, 2.952, 0.001)
# Out:
# array([ 2.95 ,  2.951])

# %%
Seconds=Image_Number/10
secondlength=filelength/10

plt.figure(figsize=(10,8))

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2,size=10)
plt.rc('xtick.minor', width=2, size=5)
plt.rc('ytick.major',width=2,size=10)
plt.rc('ytick.minor',width=2,size=5)

plt.minorticks_on()
plt.plot(Seconds[:],Data_alpha_wt[:], label='${\\alpha}$-phase', color='red',linewidth=8);
plt.plot(Seconds[:],Data_beta_wt[:],label='${\\beta}$-phase',color='blue',linewidth=8)

plt.xlabel('Time, s', fontsize=28)
plt.ylabel('Phase Fraction, wt.%', fontsize=28)

# plt.ylim(15,85)
# plt.xlim(310,340)
plt.xlim(0,secondlength)
plt.ylim(0,100)


# plt.legend()

plt.savefig('PhaseFrac_Full_{:03d}.png'.format(filenumber))

plt.show()

# %%
Seconds=Image_Number/10
secondlength=filelength/10

plt.figure(figsize=(10,8))

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2,size=10)
plt.rc('xtick.minor', width=2, size=5)
plt.rc('ytick.major',width=2,size=10)
plt.rc('ytick.minor',width=2,size=5)

plt.minorticks_on()
plt.plot(Seconds[:],Data_alpha_wt[:], label='${\\alpha}$-phase', color='red',linewidth=8);
plt.plot(Seconds[:],Data_beta_wt[:],label='${\\beta}$-phase',color='blue',linewidth=8)

plt.xlabel('Time, s', fontsize=28)
plt.ylabel('Phase Fraction, wt.%', fontsize=28)

plt.ylim(15,85)
plt.xlim(310,340)

# plt.legend()

plt.savefig('PhaseFrac_Deform_{:03d}.png'.format(filenumber))

plt.show()

# %%
plt.figure(figsize=(20,9))

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)
plt.rc('legend',fontsize=20)
plt.rc('axes',linewidth=2)
plt.rc('xtick.major',width=2,size=10)
plt.rc('xtick.minor', width=2, size=5)
plt.rc('ytick.major',width=2,size=10)
plt.rc('ytick.minor',width=2,size=5)

f, (ax, ax2) = plt.subplots(2, 1, sharex=True)

#plt.minorticks_on()
##### need to use double slash with alpha and beta characters for some reason...#####
ax.plot(Image_Number[:],Data_alpha_c[:],label='${\\alpha_c}$',color='red',linewidth=5)
ax.plot(Image_Number[:],Data_beta_a[:],label='${\\beta_a}$',color='blue',linewidth=5)
ax.plot(Image_Number[:],Data_alpha_a[:], label='${\\alpha_a}$', color='green',linewidth=5 );

ax2.plot(Image_Number[:],Data_alpha_c[:],label='${\\alpha_c}$',color='red',linewidth=5)
ax2.plot(Image_Number[:],Data_beta_a[:],label='${\\beta_a}$',color='blue',linewidth=5)
ax2.plot(Image_Number[:],Data_alpha_a[:], label='${\\alpha_a}$', color='green',linewidth=5 );

plt.xlabel('Image Number', fontsize=20)
plt.ylabel('Lattice Parameter, ${\\AA}$ ', fontsize=20)

ax.set_ylim(4.7220,4.7250)
ax2.set_ylim(2.9, 3.3)

ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop='off')  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

#plt.ylim(2.9,4.8)
#plt.xlim(0,5657)

#plt.legend()

d = .015  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

plt.show()

#plt.savefig('Lattice_brokenaxis.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
